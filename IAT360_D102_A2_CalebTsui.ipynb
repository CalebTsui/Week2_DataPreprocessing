# %% [markdown]
# <a href="https://colab.research.google.com/github/CalebTsui/Week2_DataPreprocessing/blob/D102-CalebTsui/IAT360_D102_A2_CalebTsui.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing the required libraries

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import librosa.display
import soundfile
import os

from glob import glob

import librosa
import IPython.display as ipd

# %%
audio_files = glob('Desktop/Audio Data/*/*.wav')


#Playing an audio file using IPython.display
ipd.Audio(audio_files[0])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#Emotions in the RAVDESS dataset
emotions_dict ={
  '01':'neutral',
  '02':'calm',
  '03':'happy',
  '04':'sad',
  '05':'angry',
  '06':'fearful',
  '07':'disgust',
  '08':'surprised'
}

# %%
import os, glob

def load_data():
    X,y=[],[]
    count = 0
    for file in glob.glob("Desktop/Audio Data/audio_speech_actors_01-24/Actor_*/*.wav"):
        file_name=os.path.basename(file)
        emotion=emotions_dict[file_name.split("-")[2]]
        #features = get_features(file)
        #X.append(features)
        y.append(emotion)
        count += 1
        # '\r' + end='' results in printing over same line
        print('\r' + f' Processed {count}/{1440} audio samples',end=' ')
    # Return arrays to plug into sklearn's cross-validation algorithms
    return np.array(X), np.array(y)

# %%
features, emotions = load_data()
# Out:
#  Processed 1448/1440 audio samples

# %%
# plot emotions
plt.figure(figsize=(35,4))
plt.subplot(1,3,1)
#np.unique returns ordered list of unique elements and count of each element
emotion_list, count = np.unique(emotions, return_counts=True)
plt.bar(x=range(8), height=count)
plt.xticks(ticks=range(8), labels = [emotion for emotion in emotion_list],fontsize=10)
plt.xlabel('Emotion')
plt.tick_params(labelsize=16)
plt.ylabel('Number of Samples')
plt.show()

# %%
import os, glob

def load_data():
    X,y=[],[]
    count = 0

    gender_dict ={
    'female': 0,
    'male': 0}

    for file in glob.glob("Desktop/Audio Data/audio_speech_actors_01-24/Actor_*"):
        file_name=os.path.basename(file)
        gender=int(file_name.split("_")[1])
        #features = get_features(file)
        #X.append(features)
        y.append(gender)
        count += 1
        if gender % 2 == 0:
          gender_dict["female"] += 1
        else:
          gender_dict["male"] += 1
        # '\r' + end='' results in printing over same line
        print('\r' + f' Processed {count}/{25} audio samples',end=' ')
    # Return arrays to plug into sklearn's cross-validation algorithms
    return np.array(X), np.array(y)

print(gender_dict)
# Out:
# {'female': 12, 'male': 13}

# %%
#TESTING FOR MYSELF
gender_dict ={
    'female': 0,
    'male': 0}

X,y=[],[]
count = 0
for file in glob.glob("Desktop/Audio Data/audio_speech_actors_01-24/Actor_*"):
  file_name=os.path.basename(file)
  gender=int(file_name.split("_")[1])
  y.append(gender)
  count += 1
  if gender % 2 == 0:
    gender_dict["female"] += 1
  else:
    gender_dict["male"] += 1

print(gender_dict)
# Out:
# {'female': 12, 'male': 13}

# %%
features, genders = load_data()
# Out:
#  Processed 25/25 audio samples

# %%
# plot genders
plt.figure(figsize=(35,4))
plt.subplot(1,3,1)
#np.unique returns ordered list of unique elements and count of each element
gender_dict, count = np.unique(genders, return_counts=True)
plt.bar(x=range(25), height=count)
plt.xticks(ticks=range(25), labels = [gender for gender in gender_dict],fontsize=10)
plt.xlabel('Genders')
plt.tick_params(labelsize=16)
plt.ylabel('Number of Samples')
plt.show()
